# %% [markdown]
# F1-score

# %%
from sklearn.metrics import f1_score

# %% [markdown]
# Classificazione Binaria

# %%
y_true=["A"]*9+["B"]*6
y_pred=["A"]*7+["B"]*2+["B"]*4+["A"]*2
precision=7/(7+2)
recall=7/(7+2)
f1_manuale_a=2*(precision*recall)/(precision+recall)
print (f"f1 calcolata manualmente - Classe A: {f1_manuale_a*100:.2f}")

f1_a=f1_score(y_true,y_pred,pos_label="A")
f1_b=f1_score(y_true,y_pred,pos_label="B")
print (f"F1-score calcolato con Python - Classe A: {f1_a*100:.2f}")
print (f"F1-score calcolato con Python - Classe B: {f1_b*100:.2f}")
# Out:
# f1 calcolata manualmente - Classe A: 77.78
# F1-score calcolato con Python - Classe A: 77.78
# F1-score calcolato con Python - Classe B: 66.67

# %% [markdown]
# Classificazione multiclasse

# %%
y_true=["A","A","A","B","B","B","C","C","C","A","C","B"]
y_pred=["C","C","A","B","C","B","A","A","A","A","B","B"]

f1_score_micro=f1_score(y_true,y_pred,average="micro")
f1_score_macro=f1_score(y_true,y_pred,average="macro")
f1_score_weighted=f1_score(y_true,y_pred,average="weighted")

print (f"f1_score micro: {f1_score_micro*100:.2f}%")
print (f"f1_score macro: {f1_score_macro*100:.2f}%")
print (f"f1_score weighted: {f1_score_weighted*100:.2f}%")
# Out:
# f1_score micro: 41.67%
# f1_score macro: 39.81%
# f1_score weighted: 39.81%
