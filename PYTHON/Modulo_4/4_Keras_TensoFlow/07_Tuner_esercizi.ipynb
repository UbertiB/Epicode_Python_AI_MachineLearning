# %% [markdown]
# Tuning Multi-Layer e Scelta Attivazione
# Traccia: Modifica la funzione build_model per esplorare anche:
# il numero di layer densi (da 1 a 3)
# La funzione di attivazione tra relu e tahh usando hp.choice. Esegui una RandomSearch con un massimo di 10 trial e identifica se la rete preferisce essere più profonda o più larga per risolvere il dataset
