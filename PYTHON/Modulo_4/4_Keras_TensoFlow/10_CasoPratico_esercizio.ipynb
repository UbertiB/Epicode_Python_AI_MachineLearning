# %%
#import os
import pathlib
#import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras import layers, models, applications, optimizers

# ------------------------------------------
# --- 1. CONFIGURAZIONE E SETUP AMBIENTE ---
# ------------------------------------------
# La riproducibilità è cruciale: fissare il seed garantisce che i pesi iniziali 
# shuffle e split del dataset siano identici ad ogni esecuzione.
SEED=123
tf.keras.utils.set_random_seed(SEED)

# AUTOTUNE permette al runtime di TensorFlow di regolare dinamicamente il valore di 
# parallelismo per l'estrazione dei dati in base alle risorse della CPU/GPU.
# serve per non far aspettare la GPU mentre la CPU legge/prepara i dati (immagini in questo caso)
AUTOTUNE = tf.data.AUTOTUNE #per automatizzare l'estrazione dei dati ed il loro passaggio da CPU e GPU

# ------------------------------------------
# --- 2. DATA PIPELINE (tf.data) ---  ci scarichiamo il dataset (dataset di fiori)
# ------------------------------------------
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir)
print(f"Dataset scaricato in: {data_dir}")
# scarica il dataset di fiori (.tgz) e lo estrae in una cartella temporanea (data_dir) gestita da TensorFlow.
# la struttura delle cartelle è fondamentale: ogni sottocartella rappresenta una classe, tipo, di fiore.
# le label, pertanto, sono dedotte automaticamente dal nome della cartella.
# scaricando un file compresso (.tgz) con untar=true il file è estratto automaticamente 

def get_datasets(batch_size=32, img_size=(224, 224)):  
    #il modello lavora 32 immagini alla volta, tutte le immagini vengono ridimensionate a 224x224 pixel
    #serve ridimensionare perchè MobileNetV3Large richiede input di dimensione fissa (224x224) e 3 canali (RGB)
    """
    Caricamento ottimizzato. L'uso di image_dataset_from_directory 
    astrae la gestione dei label basata sulla struttura delle cartelle.
    """
    #il modello impara sul training (aggiornando i pesi), viene valutato sulla Validation, 
    #kersas tuner scegli gli imperparametri sulla validation
    #EarlyStopping usa la validation
    #ReduceOnPlateau usa la validation
    #quindi la validation è vista centinaio di volta dal modello, anche se impara sul training
    #pertanto il dataset deve essere diviso in trainig, validation e test.
    #il test resta nascosto fino alla fine, utilizzato solo per valutare le performance finali con model.evaluate(test_ds)

    #dataset di training 70% (risesrva il 30% per la validation)
    #traing_ds non contiene più immagini ma contiene batch di immagini (batch di 32 immagini)
    train_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir, validation_split=0.3, subset="training", seed=SEED, 
        image_size=img_size, batch_size=batch_size
    )
    #dataset di validation
    remaining_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir, validation_split=0.3, subset="validation", seed=SEED, 
        image_size=img_size, batch_size=batch_size
    )
    # Numero batch del dataset rimanente
    remaining_batches = tf.data.experimental.cardinality(
        remaining_ds
    ).numpy()    
    # 15% validation
    val_ds = remaining_ds.take(remaining_batches // 2)

    # 15% test
    test_ds = remaining_ds.skip(remaining_batches // 2)    
    
    # .cache(): mantiene i dati in memoria dopo la prima lettura, evitando colli di bottiglia dall'I/O del disco.
    # .shuffle(1000): garantisce che il modello non impari l'ordine dei dati (importante per la convergenza).
    # .prefetch(): prepara il batch successivo mentre la GPU sta elaborando il corrente (sovrapposizione CPU/GPU).
    train_ds = train_ds.cache().shuffle(1000).prefetch(AUTOTUNE)
    val_ds = val_ds.cache().prefetch(AUTOTUNE)
    test_ds = test_ds.cache().prefetch(AUTOTUNE)

    return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = get_datasets() 

# --- 3. MODELLO CON HYPERPARAMETER TUNING (Bayesian Optimization) ---
#questa funzione costriusce il modello Keras. Il parametro hp è un oggetto di Keras Tuner che scegli gli iperparametri
#gli iperparametri sono valori che decidi tu prima dell'addestramento (learning rate, dropout, numero di layer, numero di neuroni per layer, ecc., batch size, ecc.))
def build_model(hp):
    """
    Costruisce il modello definendo lo spazio di ricerca. A differenza del Grid Search, 
    l'ottimizzazione Bayesiana impara dai tentativi precedenti per trovare il setup ottimale.
    """
    # Spazio di ricerca per Learning Rate (logaritmico per coprire diversi ordini di grandezza)
    hp_lr = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
    # Dropout per prevenire l'overfitting (regolarizzazione)
    hp_dropout = hp.Float('dropout', 0.2, 0.5, step=0.1)
    #prova come dropout 0.2, 0.3, 0.4, 0.5 (step=0.1)
    #il dropout spegne casualmente una parte di neuroni durante l'addestramento (training) per evitare l'overfitting
    
    # MobileNetV3Large: Architettura basata su Hard-Swish activation e Squeeze-and-Excitation.
    # Ideale per performance elevate con basso costo computazionale.
    #prendi una rete già addestrata su ImageNet (MobileNetV3Large) e la adatti al tuo problema (Transfer Learning)
    #MobileNetV3Large include già il preprocessing/rescaling nel modello e si aspetta pixel in range 0-255    
    base_model = applications.MobileNetV3Large(
        input_shape=(224, 224, 3), 
        include_top=False, #tolgo la testa (ultimo layer) perchè voglio fare classificazione su 5 classi, non sulle 1000 di ImageNet
        weights='imagenet' #carico pesi già addestrati su ImageNet
    )
    
    # Freeze iniziale: non aggiorniamo i pesi del backbone per non distruggere 
    # le feature già apprese (bordi, forme) durante il tuning iniziale.
    base_model.trainable = False #blocco i pesi di MobileNet, durante il training non vengono modificati, vengono modificati solo i pesi dei layer aggiunti dopo (GlobalAveragePooling2D, Dropout, Dense)
    
    #modello sequenziale: aggiungo layer uno dopo l'altro
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        
        # Data Augmentation integrata nel grafo: avviene in tempo reale su GPU.
        # Rende il modello robusto a variazioni di angolazione e zoom.
        #LAYERS DI DATA AUGMENTATION (per la parte di vision)
        #per aumentare i dati
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        
        #passo l'immagine dentro MobileNet, che estrae feature complesse (bordi, forme, texture) senza bisogno di addestrare da zero.
        base_model,
        # Riduce la dimensionalità da (7, 7, 960) a (960,) calcolando la media, 
        # riducendo drasticamente il numero di parametri rispetto a un layer Flatten.
        layers.GlobalAveragePooling2D(), #riduce la dimensionalità
        layers.Dropout(hp_dropout), #per ottimizzare
        layers.Dense(128, activation='relu'), #Layer denso con 128 neuroni e attivazione ReLU
        layers.Dropout(hp_dropout), #per ottimizzare
        layers.Dense(5, activation='softmax') # Softmax per classificazione multi-classe mutua esclusiva
        #5 neuroni in output perchè ho 5 classi di fiori, softmax per avere la probabilità di appartenenza a ciascuno 
    ])
    
    #compilazione modello: definisco ottimizzatore, loss e metriche da monitorare
    model.compile(
        optimizer=optimizers.Adam(learning_rate=hp_lr),
        loss='sparse_categorical_crossentropy', # Usata perché le label sono interi, non one-hot encoded
        metrics=['accuracy']
    )
    #adam aggiorna i pesi del modello in base al gradiente della loss rispetto ai pesi
    #learning_rate=hp_lr usa il learning rate scelto dal tuner
    #sparse_categorical_crossentropy è la loss più adatta per classificazione multi-classe con label interi (0,1,2,3,4)
    #se invece le label fossero one-hot encoded (es. [1,0,0,0,0] per la classe 0) si userebbe categorical_crossentropy
    return model

#OTTIMIZZAZIONE IPER-PARAMETRI

#KERAS TUNER: strumento per ottimizzare automaticamente gli iperparametri del modello (learning rate, dropout, ecc.)
# Configurazione del Tuner: BayesianOptimization è più efficiente del RandomSearch
# poiché modella probabilisticamente la funzione obiettivo.
tuner = kt.BayesianOptimization(
    build_model,
    objective='val_accuracy',
    max_trials=5, #5 tentativi per parametri
    directory='tuning_logs',
    project_name='flower_classification_2025'
)
#dico a Keras di costruire il modello usando build_model, cambiare learning rate e dropout, 
#e scegliere quello con migliore val_accuracy
print("--- Ricerca Bayesiana del miglior set di Iperparametri ---")
tuner.search(train_ds, epochs=5, validation_data=val_ds) #5 epoche
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0] #prende la combinazione migliore

# --- 4. CALLBACKS E ADDESTRAMENTO FINALE ---

# Ricostruiamo il modello con i parametri vincenti trovati dal tuner
model = tuner.hypermodel.build(best_hps)
# salvo il modello migliore sulla validation accuracy, interrompo l'addestramento se la loss non scende più, e riduco il learning rate se il modello smette di imparare.
callbacks = [
    # Salvataggio nel nuovo formato .keras: più sicuro e leggero del vecchio .h5
    tf.keras.callbacks.ModelCheckpoint(
        'best_model_2025.keras', monitor='val_accuracy', save_best_only=True, verbose=1
    ),
    # EarlyStopping: interrompe l'addestramento se la loss non scende più, 
    # evitando spreco di risorse e overfitting.
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=10, restore_best_weights=True, verbose=1
    ),
    # ReduceLROnPlateau: se il modello smette di imparare, "rallenta" per esplorare 
    # con più precisione i minimi della funzione di perdita.
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1 #se la val_loss non migliora per 5 epoche, dimezza il learning rate, ma non scendere sotto 1e-7
    )
]

# ADDESTRAMENTO FINALE
print(f"--- Addestramento finale con LR: {best_hps.get('learning_rate')} ---")
# Epochs=50 è un limite superiore; EarlyStopping probabilmente fermerà il processo prima.
history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=2, 
    callbacks=callbacks
)

# --- 5. VISUALIZZAZIONE PERFORMANCE ---
# GRAFICI

def plot_metrics(history):
    """Utility per analizzare il gap tra training e validation (segnale di overfitting)."""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy', lw=2)
    plt.plot(val_acc, label='Validation Accuracy', lw=2)
    plt.title('Evoluzione Accuracy')
    plt.grid(True, alpha=0.3)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss', lw=2)
    plt.plot(val_loss, label='Validation Loss', lw=2)
    plt.title('Evoluzione Loss')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()

plot_metrics(history)

# --- 6. TFLITE 8-BIT FULL INTEGER QUANTIZATION ---

# La quantizzazione trasforma i pesi da float32 (4 byte) a int8 (1 byte).
# Questo riduce la dimensione del modello di 4x e velocizza l'inferenza su dispositivi mobili.


def representative_data_gen():
    """
    Essenziale per la quantizzazione intera: fornisce un piccolo set di dati reali 
    per calibrare il range dinamico (min/max) delle attivazioni.
    """
    for input_value, _ in val_ds.take(20):
        yield [input_value]

print("--- Conversione in TFLite (8-bit Quantization) ---")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen

# Forziamo l'uso di soli operatori interi. Se un'operazione non è supportata, il converter darà errore.
# Questo garantisce la compatibilità con acceleratori hardware come la Google Coral Edge TPU.
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.uint8 # Input come immagine 0-255
converter.inference_output_type = tf.uint8 # Output come probabilità quantizzata

tflite_model_quant = converter.convert()

with open('model_quantized_8bit.tflite', 'wb') as f:
    f.write(tflite_model_quant)

print("\nPipeline completata! Modelli pronti per il deployment.")
# Out:
# Dataset scaricato in: C:\Users\uberti\.keras\datasets\flower_photos
# Found 3670 files belonging to 1 classes.
# Using 2569 files for training.
# Found 3670 files belonging to 1 classes.
# Using 1101 files for validation.
# Reloading Tuner from tuning_logs\flower_classification_2025\tuner0.json
# --- Ricerca Bayesiana del miglior set di Iperparametri ---
# --- Addestramento finale con LR: 0.0013489304109835225 ---
# Epoch 1/2
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.9158 - loss: 0.2823
# Epoch 1: val_accuracy improved from None to 1.00000, saving model to best_model_2025.keras
#
# Epoch 1: finished saving model to best_model_2025.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 92s 700ms/step - accuracy: 0.9813 - loss: 0.0621 - val_accuracy: 1.0000 - val_loss: 2.7559e-05 - learning_rate: 0.0013
# Epoch 2/2
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 628ms/step - accuracy: 1.0000 - loss: 4.5398e-05
# Epoch 2: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 62s 768ms/step - accuracy: 1.0000 - loss: 6.1120e-05 - val_accuracy: 1.0000 - val_loss: 2.3014e-05 - learning_rate: 0.0013
# Restoring model weights from the end of the best epoch: 2.
# --- Conversione in TFLite (8-bit Quantization) ---
# INFO:tensorflow:Assets written to: C:\Users\uberti\AppData\Local\Temp\tmpdos4ih_c\assets
# INFO:tensorflow:Assets written to: C:\Users\uberti\AppData\Local\Temp\tmpdos4ih_c\assets
# Saved artifact at 'C:\Users\uberti\AppData\Local\Temp\tmpdos4ih_c'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_416')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   2775546799184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546799568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546804176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546798416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546798992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546800912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546800336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546799952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546801296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546797264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546798032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546797840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546795920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546803792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546802640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546798224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546797456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546803600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546803984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546801872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546803024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546800720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546800528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546798800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546801488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546802832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546802448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546802064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546797648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546797072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546801104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546796880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546794576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546803216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546795344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546796688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546796496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546796304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546802256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546795152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546795728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546794000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546794960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546801680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546793616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546791504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546793808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546792656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546792464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546794768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546795536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546794192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046126608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546794384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2775546796112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046126032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046125456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046127760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046127184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046127376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046128720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046126416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046126800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046129296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046128144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046128912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046128528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046127568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046130256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046129104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046129680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046130448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046128336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046131024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046130064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046130640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046130832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780046129488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047180048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047181200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047181008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047180624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047181776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047180240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047181392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047181584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047179856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047182736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047182160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047182352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047182544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047180432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047183696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047183120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047180816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047184464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047183888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047184848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047183312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047181968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047184656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047185424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047184080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047182928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047185232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047183504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047186384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047185808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047186000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047186192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047184272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047187344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047186768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047186960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047187152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047185040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047188304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047187728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047187920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047188112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047185616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047189264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047188688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047188880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047189072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047186576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047190224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047189648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047189840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047190032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047187536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047191184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047190608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047190800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047190992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047188496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047192144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047191568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047191760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047191952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047189456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047193104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047192528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047192720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047192912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047190416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047194064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047193488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047193680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047193872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047191376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047195024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047194448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047194640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047195408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047192336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047195984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047194832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047195600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047193296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047195792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047195216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780047194256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048082128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048081936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048081552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048082704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048081168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048082320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048082512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048081744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048083664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048083088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048081360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048084432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048083856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048084816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048083280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048080976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048084624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048085392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048084048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048082896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048085200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048083472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048086352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048085776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048085968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048086160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048084240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048087312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048086736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048085008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048088080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048087504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048088464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048086928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048085584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048088272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048089040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048087696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048086544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048088848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048087120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048090000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048089424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048089616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048089808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048087888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048090960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048090384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048088656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048091728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048091152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048092112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048090576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048089232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048091920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048092688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048091344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048090192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048092496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048090768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048093648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048093072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048093264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048093456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048091536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048094608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048094032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048092304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048095376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048094800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048095760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048094224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048092880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048095568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048096336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048094992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048093840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048095952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048097104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048096528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048095184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048096720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048096912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048096144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780048094416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050129168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050129744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050130704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050129936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050131088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050130320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050128976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050130896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050131664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050129360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050129552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050131472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050130128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050132624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050132816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050133968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050134928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2780050134160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\uberti\.conda\envs\ai_epicode\Lib\site-packages\tensorflow\lite\python\convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Pipeline completata! Modelli pronti per il deployment.
